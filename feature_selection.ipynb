# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
from sklearn.feature_selection import SelectKBest, chi2
df= pd.read_excel("C:\\Users\\ST\\Downloads\\archive (1)\\Date_Fruit_Datasets\\Date_Fruit_Datasets.xlsx")
X= df.iloc[:,:10]
#print(X.head())
# Select last column of dataframe as a series
y = df.iloc[:,-1]
print(df.head())
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0  422163   2378.908    837.8484    645.6693        0.6373  733.1539
# 1  338136   2085.144    723.8198    595.2073        0.5690  656.1464
# 2  526843   2647.394    940.7379    715.3638        0.6494  819.0222
# 3  416063   2351.210    827.9804    645.2988        0.6266  727.8378
# 4  347562   2160.354    763.9877    582.8359        0.6465  665.2291
#
#    SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0    0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1    0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2    0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3    0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4    0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
#
#    KurtosisRB    EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  ALLdaub4RG  \
# ...

# %%
import matplotlib.pyplot as plt

sns.pairplot(df,hue="Class")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5128/2978237761.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 sns.pairplot(df,hue="Class")
#       4 plt.show()
#
# ~\anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# ...

# %%
df
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1    338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2    526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3    416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4    347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# ..      ...        ...         ...         ...           ...       ...
# 893  255403  1925.3650    691.8453    477.1796        0.7241  570.2536
# 894  365924  2664.8230    855.4633    551.5447        0.7644  682.5752
# 895  254330  1926.7360    747.4943    435.6219        0.8126  569.0545
# 896  238955  1906.2679    716.6485    441.8297        0.7873  551.5859
# 897  343792  2289.2720    823.8438    534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# ...

# %%
df.columns
# Out:
# Index(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'EQDIASQ', 'SOLIDITY', 'CONVEX_AREA', 'EXTENT', 'ASPECT_RATIO',
#        'ROUNDNESS', 'COMPACTNESS', 'SHAPEFACTOR_1', 'SHAPEFACTOR_2',
#        'SHAPEFACTOR_3', 'SHAPEFACTOR_4', 'MeanRR', 'MeanRG', 'MeanRB',
#        'StdDevRR', 'StdDevRG', 'StdDevRB', 'SkewRR', 'SkewRG', 'SkewRB',
#        'KurtosisRR', 'KurtosisRG', 'KurtosisRB', 'EntropyRR', 'EntropyRG',
#        'EntropyRB', 'ALLdaub4RR', 'ALLdaub4RG', 'ALLdaub4RB', 'Class'],
#       dtype='object')

# %%
col_list = ["AREA", "PERIMETER","MAJOR_AXIS","MINOR_AXIS","EQDIASQ","CONVEX_AREA","Class"]
df1= pd.read_excel("C:\\Users\\ST\\Downloads\\archive (1)\\Date_Fruit_Datasets\\Date_Fruit_Datasets.xlsx", usecols=col_list)

# %%
import matplotlib.pyplot as plt

sns.pairplot(df1,hue="Class")
plt.show()

# %%
df1.head()
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS   EQDIASQ  CONVEX_AREA  Class
# 0  422163   2378.908    837.8484    645.6693  733.1539       424428  BERHI
# 1  338136   2085.144    723.8198    595.2073  656.1464       339014  BERHI
# 2  526843   2647.394    940.7379    715.3638  819.0222       528876  BERHI
# 3  416063   2351.210    827.9804    645.2988  727.8378       418255  BERHI
# 4  347562   2160.354    763.9877    582.8359  665.2291       350797  BERHI

# %%
X= df.iloc[:,:-1]
#print(X.head())
# Select last column of dataframe as a series
y = df.iloc[:,-1]

# %%
from sklearn.feature_selection import chi2,SelectKBest

# %%
best_features= SelectKBest(score_func=chi2, k=7)
import sklearn.preprocessing 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
scaler.transform(X)
# Out:
# array([[0.77227446, 0.77207865, 0.56560444, ..., 0.67351302, 0.55053709,
#         0.4946647 ],
#        [0.61783464, 0.61747978, 0.43690403, ..., 0.53892305, 0.51634149,
#         0.49450116],
#        [0.96467405, 0.9133745 , 0.6817325 , ..., 0.77796738, 0.61978216,
#         0.57350706],
#        ...,
#        [0.46380101, 0.53411457, 0.46362467, ..., 0.44774729, 0.32417389,
#         0.36261751],
#        [0.43554209, 0.52334284, 0.42881001, ..., 0.55750041, 0.40280492,
#         0.45206697],
#        [0.62823025, 0.72490601, 0.5497979 , ..., 0.4974535 , 0.29056351,
#         0.33754565]])

# %%
X_new = SelectKBest(chi2, k=5).fit_transform(X, y)
print(X_new.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5128/3160983839.py in <module>
# ----> 1 X_new = SelectKBest(chi2, k=5).fit_transform(X, y)
#       2 print(X_new.shape)
#
# ~\anaconda\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
# --> 702             return self.fit(X, y, **fit_params).transform(X)
#     703
#     704
#
# ~\anaconda\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     351
#     352         self._check_params(X, y)
# --> 353         score_func_ret = self.score_func(X, y)
#     354         if isinstance(score_func_ret, (list, tuple)):
#     355             self.scores_, self.pvalues_ = score_func_ret
#
# ...

# %% [markdown]
# # Feature selection

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model= ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.06024984 0.06936477 0.04087159 0.06296801 0.02586108 0.03807617
#  0.0162642  0.04153179 0.01181691 0.02102848 0.02035925 0.01643082
#  0.03301672 0.02944943 0.01434003 0.01085776 0.0303172  0.03193143
#  0.02443522 0.01053176 0.01433644 0.01791112 0.02380317 0.03440044
#  0.02954591 0.01290507 0.01966956 0.02249508 0.04402383 0.03275114
#  0.02899289 0.03962989 0.03737459 0.0324584 ]

# %%
features_importance=pd.Series(model.feature_importances_,index=X.columns)
features_importance.nlargest(10).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df_full= pd.read_excel("C:\\Users\\ST\\Downloads\\archive (1)\\Date_Fruit_Datasets\\Date_Fruit_Datasets.xlsx")

X= df_full.iloc[:,:-1]
# Select last column of dataframe as a series
y = df_full.iloc[:,-1]

# %%
model= ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_)
# Out:
# [0.05484191 0.04624816 0.03753316 0.04425286 0.02236542 0.05334893
#  0.01679509 0.0582614  0.01151904 0.01695521 0.0238884  0.016137
#  0.04125455 0.03573451 0.01822721 0.01138997 0.04389968 0.03813958
#  0.02401048 0.01181479 0.01251855 0.01167385 0.02000237 0.03175986
#  0.02990263 0.01942012 0.02016081 0.01963987 0.03478563 0.04114155
#  0.03081996 0.04349437 0.02881949 0.02924358]

# %%
features_importance=pd.Series(model.feature_importances_,index=X.columns)
features_importance.nlargest(20).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
print(df.columns)
X1= df[["CONVEX_AREA","AREA","EQDIASQ","PERIMETER","MINOR_AXIS","MeanRR","ALLdaub4RR","SHAPEFACTOR_1","EntropyRG","MeanRG",
        "MAJOR_AXIS","SHAPEFACTOR_2","EntropyRR","SkewRG","EntropyRB","SkewRB","ALLdaub4RB","ALLdaub4RG","MeanRB","ROUNDNESS"]]
y=df[["Class"]]
#print(X1.head())
# Out:
# Index(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'EQDIASQ', 'SOLIDITY', 'CONVEX_AREA', 'EXTENT', 'ASPECT_RATIO',
#        'ROUNDNESS', 'COMPACTNESS', 'SHAPEFACTOR_1', 'SHAPEFACTOR_2',
#        'SHAPEFACTOR_3', 'SHAPEFACTOR_4', 'MeanRR', 'MeanRG', 'MeanRB',
#        'StdDevRR', 'StdDevRG', 'StdDevRB', 'SkewRR', 'SkewRG', 'SkewRB',
#        'KurtosisRR', 'KurtosisRG', 'KurtosisRB', 'EntropyRR', 'EntropyRG',
#        'EntropyRB', 'ALLdaub4RR', 'ALLdaub4RG', 'ALLdaub4RB', 'Class'],
#       dtype='object')

# %%
print(y.head())
# Out:
#    Class
# 0  BERHI
# 1  BERHI
# 2  BERHI
# 3  BERHI
# 4  BERHI

# %% [markdown]
# # Train and test the dataset

# %% [markdown]
# ## KNN

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
X1, y, test_size=0.10, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# C:\Users\ST\anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.65

# %% [markdown]
# ## Random forest

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X1,y,test_size=0.2,random_state=50)
ss= StandardScaler()
classifer= RandomForestRegressor()
classifer.fit(X_train,y_train)
# Out:
# C:\Users\ST\AppData\Local\Temp/ipykernel_5128/3926078963.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifer.fit(X_train,y_train)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5128/3926078963.py in <module>
#       5 ss= StandardScaler()
#       6 classifer= RandomForestRegressor()
# ----> 7 classifer.fit(X_train,y_train)
#
# ~\anaconda\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     332
#     333         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 334             y = np.ascontiguousarray(y, dtype=DOUBLE)
#     335
#     336         if expanded_class_weight is not None:
#
# ...

# %% [markdown]
# ## logistic regression

# %%
from sklearn.linear_model import LogisticRegression

logistic_reg= LogisticRegression()

# %%
logistic_reg.fit(X_train,y_train)
# Out:
# C:\Users\ST\anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\ST\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_reg.score(X_test,y_test)
# Out:
# 0.5833333333333334

# %% [markdown]
# ## checking score of classification

# %%
from sklearn import metrics
y_predct= logistic_reg.predict(X1)
metrics.accuracy_score(y,y_predct)
# Out:
# 0.5556792873051225

# %%
from sklearn import metrics
y_predct= knn.predict(X1)
metrics.accuracy_score(y,y_predct)
# Out:
# 0.9298440979955457

# %% [markdown]
# ## using hot encoder

# %%
df["Class"].unique()
# Out:
# array(['BERHI', 'DEGLET', 'DOKOL', 'IRAQI', 'ROTANA', 'SAFAVI', 'SOGAY'],
#       dtype=object)

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score

# %%
col_transformer= make_column_transformer((OneHotEncoder(),["Class"]))

# %%
model= LogisticRegression(solver="lbfgs")

# %%
pipe= make_pipeline(col_transformer,model)

# %%
cross_val_score(pipe,X1,y,cv=5, scoring="accuracy").mean()
# Out:
# C:\Users\ST\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ST\anaconda\lib\site-packages\pandas\core\indexes\base.py", line 3361, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 76, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 108, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5198, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5206, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...

# %%
X1= df[["CONVEX_AREA","AREA","EQDIASQ","PERIMETER","MINOR_AXIS","MeanRR","ALLdaub4RR","SHAPEFACTOR_1","EntropyRG","MeanRG",
        "MAJOR_AXIS","SHAPEFACTOR_2","EntropyRR","SkewRG","EntropyRB","SkewRB","ALLdaub4RB","ALLdaub4RG","MeanRB","ROUNDNESS"]]
y=df[["Class"]]
